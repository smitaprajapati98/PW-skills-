# %% [markdown]
# # Q1. Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation of 5 using Python. Interpret the results.

# %%
import scipy.stats as stats

# Sample data
sample_mean = 50
sample_std = 5
sample_size = 80

# Calculate the 95% confidence interval
confidence_level = 0.95
margin_of_error = stats.norm.ppf((1 + confidence_level) / 2) * (sample_std / (sample_size ** 0.5))
confidence_interval = (sample_mean - margin_of_error, sample_mean + margin_of_error)

print("95% Confidence Interval:", confidence_interval)
# Out:
# 95% Confidence Interval: (48.90434682427927, 51.09565317572073)

# %% [markdown]
# # Q2. Conduct a chi-square goodness of fit test to determine if the distribution of colors of M&Ms in a bag matches the expected distribution of 20% blue, 20% orange, 20% green, 10% yellow, 10% red, and 20% brown. Use Python to perform the test with a significance level of 0.05.

# %%
import numpy as np
import scipy.stats as stats

# Observed frequencies of colors in the sample bag
observed_frequencies = np.array([30, 25, 20, 15, 10, 20])

# Expected frequencies based on the expected distribution
expected_frequencies = np.array([0.2, 0.2, 0.2, 0.1, 0.1, 0.2]) * np.sum(observed_frequencies)

# Perform the chi-square goodness of fit test
chi2_stat, p_value = stats.chisquare(observed_frequencies, f_exp=expected_frequencies)

print("Chi-square statistic:", chi2_stat)
print("P-value:", p_value)
# Out:
# Chi-square statistic: 3.9583333333333335
# P-value: 0.5554304329530974

# %% [markdown]
# # Q3. Use Python to calculate the chi-square statistic and p-value for a contingency table with the following data:Interpret the results of the test.

# %%
import numpy as np
import scipy.stats as stats

# Contingency table data
observed_data = np.array([[50, 30], [20, 40]])

# Perform the chi-square test
chi2_stat, p_value, _, _ = stats.chi2_contingency(observed_data)

print("Chi-square statistic:", chi2_stat)
print("P-value:", p_value)
# Out:
# Chi-square statistic: 10.529166666666667
# P-value: 0.0011750518530845063

# %% [markdown]
# # Q4. A study of the prevalence of smoking in a population of 500 individuals found that 60 individuals smoked. Use Python to calculate the 95% confidence interval for the true proportion of individuals in the population who smoke.

# %%
import statsmodels.api as sm

# Sample data
sample_size = 500
number_smokers = 60

# Calculate the proportion of smokers in the sample
sample_proportion = number_smokers / sample_size

# Calculate the standard error
standard_error = (sample_proportion * (1 - sample_proportion) / sample_size) ** 0.5

# Calculate the 95% confidence interval
confidence_level = 0.95
margin_of_error = sm.stats.proportion_confint(number_smokers, sample_size, alpha=1-confidence_level, method='normal')

confidence_interval = (sample_proportion - margin_of_error[0], sample_proportion + margin_of_error[1])

print("95% Confidence Interval:", confidence_interval)
# Out:
# 95% Confidence Interval: (0.028483611128692923, 0.2684836111286929)

# %% [markdown]
# # Q5. Calculate the 90% confidence interval for a sample of data with a mean of 75 and a standard deviation of 12 using Python. Interpret the results.

# %%
import scipy.stats as stats

# Sample data
sample_mean = 75
sample_std = 12
sample_size = 90 

# Calculate the 90% confidence interval
confidence_level = 0.90
margin_of_error = stats.norm.ppf((1 + confidence_level) / 2) * (sample_std / (sample_size ** 0.5))
confidence_interval = (sample_mean - margin_of_error, sample_mean + margin_of_error)

print("90% Confidence Interval:", confidence_interval)
# Out:
# 90% Confidence Interval: (72.91940644849777, 77.08059355150223)

# %% [markdown]
# # Q6. Use Python to plot the chi-square distribution with 10 degrees of freedom. Label the axes and shade the area corresponding to a chi-square statistic of 15.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Degrees of freedom for the chi-square distribution
df = 10

# Range of values for the x-axis
x = np.linspace(0, 30, 1000)

# Probability density function (pdf) for the chi-square distribution
pdf = stats.chi2.pdf(x, df)

# Plot the chi-square distribution
plt.plot(x, pdf, label=f"Chi-square df={df}")
plt.fill_between(x, pdf, where=(x >= 15), color='gray', alpha=0.5)

# Label the axes
plt.xlabel("Chi-square statistic")
plt.ylabel("Probability density")

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # Q7. A random sample of 1000 people was asked if they preferred Coke or Pepsi. Of the sample, 520 preferred Coke. Calculate a 99% confidence interval for the true proportion of people in the population who prefer Coke.

# %%
import statsmodels.api as sm

# Sample data
sample_size = 1000
number_preferred_coke = 520

# Calculate the proportion of people who preferred Coke in the sample
sample_proportion = number_preferred_coke / sample_size

# Calculate the standard error
standard_error = (sample_proportion * (1 - sample_proportion) / sample_size) ** 0.5

# Calculate the 99% confidence interval
confidence_level = 0.99
margin_of_error = sm.stats.proportion_confint(number_preferred_coke, sample_size, alpha=1-confidence_level, method='normal')

confidence_interval = (sample_proportion - margin_of_error[0], sample_proportion + margin_of_error[1])

print("99% Confidence Interval:", confidence_interval)
# Out:
# 99% Confidence Interval: (0.040694842322030134, 1.0806948423220302)

# %% [markdown]
# # Q8. A researcher hypothesizes that a coin is biased towards tails. They flip the coin 100 times and observe 45 tails. Conduct a chi-square goodness of fit test to determine if the observed frequencies match the expected frequencies of a fair coin. Use a significance level of 0.05.

# %%
import numpy as np
import scipy.stats as stats

# Observed frequencies of tails and heads
observed_frequencies = np.array([45, 100 - 45])

# Expected frequencies for a fair coin
expected_frequencies = np.array([50, 50])

# Perform the chi-square goodness of fit test
chi2_stat, p_value = stats.chisquare(observed_frequencies, f_exp=expected_frequencies)

print("Chi-square statistic:", chi2_stat)
print("P-value:", p_value)
# Out:
# Chi-square statistic: 1.0
# P-value: 0.31731050786291115

# %% [markdown]
# # Q9. A study was conducted to determine if there is an association between smoking status (smoker or non-smoker) and lung cancer diagnosis (yes or no). The results are shown in the contingency table below. Conduct a chi-square test for independence to determine if there is a significant association between smoking status and lung cancer diagnosis.Use a significance level of 0.05

# %%
import numpy as np
import scipy.stats as stats

# Contingency table data
observed_data = np.array([[150, 50], [200, 100]])

# Perform the chi-square test for independence
chi2_stat, p_value, _, _ = stats.chi2_contingency(observed_data)

print("Chi-square statistic:", chi2_stat)
print("P-value:", p_value)
# Out:
# Chi-square statistic: 3.581349206349206
# P-value: 0.058431675464333054

# %% [markdown]
# # Q10. A study was conducted to determine if the proportion of people who prefer milk chocolate, dark chocolate, or white chocolate is different in the U.S. versus the U.K. A random sample of 500 people from the U.S. and a random sample of 500 people from the U.K. were surveyed. The results are shown in the contingency table below. Conduct a chi-square test for independence to determine if there is a significant association between chocolate preference and country of origin.Use a significance level of 0.01.

# %%
import numpy as np
import scipy.stats as stats

# Contingency table data
observed_data = np.array([[200, 150, 150], [250, 200, 50]])

# Perform the chi-square test for independence
chi2_stat, p_value, _, _ = stats.chi2_contingency(observed_data)

print("Chi-square statistic:", chi2_stat)
print("P-value:", p_value)
# Out:
# Chi-square statistic: 62.698412698412696
# P-value: 2.4277986774046572e-14

# %% [markdown]
# # Q11. A random sample of 30 people was selected from a population with an unknown mean and standard deviation. The sample mean was found to be 72 and the sample standard deviation was found to be 10. Conduct a hypothesis test to determine if the population mean is significantly different from 70. Use a significance level of 0.05

# %%
import scipy.stats as stats

# Sample data
sample_mean = 72
sample_std = 10
sample_size = 30
population_mean = 70

# Null hypothesis (H0): Population mean is 70
# Alternative hypothesis (Ha): Population mean is different from 70 (two-tailed test)

# Perform the t-test
t_stat, p_value = stats.ttest_1samp([sample_mean], popmean=population_mean)

print("T-statistic:", t_stat)
print("P-value:", p_value)
# Out:
# T-statistic: nan
# P-value: nan
